# %% [markdown]
# <a href="https://colab.research.google.com/github/vivian-amorim/fase6cap1/blob/main/FarmTechTeam_Fase6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Projeto: Classificação de Banana x Garrafa de Água
# **Fase 6 – FarmTech Solutions**

# %% [markdown]
# ## Objetivo
# Desenvolver um modelo de visão computacional para classificar imagens de **bananas** e **garrafa de água** usando YOLOv5 (30 épocas) e documentar os resultados.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Dataset
# - Foram utilizadas 40 imagens de cada classe:
#   - Banana
#   - Garrafa de Água
# - As imagens foram separadas em pastas:
#   - Treino: 32 imagens por classe
#   - Validação: 4 imagens por classe
#   - Teste: 4 imagens por classe
# - Estrutura de pastas no Google Drive:

# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !pip install -r requirements.txt
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.
# /content/yolov5
# ...

# %% [markdown]
# ⚙️ Configuração do Ambiente
#
# O ambiente foi configurado no Google Colab, instalando o YOLOv5 e conectando ao Google Drive.
# O arquivo data.yaml foi criado para indicar os caminhos das pastas de treino e validação.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Rotulagem das imagens
# - As imagens de treino foram rotuladas usando o **Make Sense AI**.
# - As classes definidas foram `bananas` e `garrafas`.
# - Os arquivos de label foram exportados em formato YOLO e salvos na pasta `labels/` correspondente.

# %%
# %%writefile /content/drive/MyDrive/dataset_yolo/data.yaml
# train: /content/drive/MyDrive/dataset_yolo/train
# val: /content/drive/MyDrive/dataset_yolo/val
# nc: 2
# names: ['banana', 'garrafa']
# Out:
# Writing /content/drive/MyDrive/dataset_yolo/data.yaml

# %%
# !python train.py --img 640 --batch 16 --epochs 30 --data /content/drive/MyDrive/dataset_yolo/data.yaml --weights yolov5s.pt
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-10-13 23:02:14.817124: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1760396534.854719   11467 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1760396534.866289   11467 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1760396534.895696   11467 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python train.py \
  --img 640 \
  --batch 16 \
  --epochs 60 \
  --data /content/drive/MyDrive/dataset_yolo/data.yaml \
  --weights runs/train/exp2/weights/last.pt \
  --project runs/train \
  --name exp3 \
  --exist-ok
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-10-13 23:31:15.853166: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1760398275.885757   18915 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1760398275.895799   18915 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1760398275.919927   18915 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
cp -r runs/train/exp3 /content/drive/MyDrive/YOLOv5_resultados_60_epocas/
